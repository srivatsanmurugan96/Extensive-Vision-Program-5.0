# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/intel-isl/MiDaS.git
# Out:
# Cloning into 'MiDaS'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 154 (delta 2), reused 6 (delta 1), pack-reused 144
# Receiving objects: 100% (154/154), 42.50 KiB | 4.72 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
# !cp "/content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/data/customdata/images" "/content/gdrive/My Drive/EVA/Session14/MiDaS-master/input/"
# Out:
# cp: -r not specified; omitting directory '/content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/data/customdata/images'

# %%
# !unzip "/content/gdrive/My Drive/EVA/Session14/input.zip" -d "/content/gdrive/My Drive/EVA/Session14/MiDaS-master/"
# Out:
# Archive:  /content/gdrive/My Drive/EVA/Session14/input.zip
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/.DS_Store
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/_112919912_gettyimages-1220030093.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/01-prince-boots - Copy.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/026f0ffddc.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/032620_LS_covid-masks_inline-680.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/046acbc8e1.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/050bdc8229cf18030e2d8a266dd334af84-23-chelsea-boots.rsquare.w1200 - Copy.jpg
#   inflating: /content/gdrive/My Drive/EVA/Session14/MiDaS-master/images/051fa0f9fd.jpg
# ...

# %%
cd /content/gdrive/My Drive/EVA/Session14/MiDaS-master/
# Out:
# /content/gdrive/My Drive/EVA/Session14/MiDaS-master

# %%
# !python run.py
# Out:
# initialize
# device: cpu
# Loading weights:  model-f46da743.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:04<00:00, 88.4MB/s]
# start processing
#   processing input/Kg.jpg (1/3585)
#   processing input/K153.jpg (2/3585)
#   processing input/Kc.jpg (3/3585)
#   processing input/Krr.jpg (4/3585)
#   processing input/K214.jpg (5/3585)
#   processing input/Ky.jpg (6/3585)
#   processing input/K260.jpg (7/3585)
#   processing input/K271.jpg (8/3585)
#   processing input/K157.jpg (9/3585)
#   processing input/majdoor_39.jpg (10/3585)
#   processing input/majdoor_141.jpg (11/3585)
#   processing input/majdoor_180.jpg (12/3585)
#   processing input/majdoor_223.jpg (13/3585)
#   processing input/majdoor_165.jpg (14/3585)
# ...
