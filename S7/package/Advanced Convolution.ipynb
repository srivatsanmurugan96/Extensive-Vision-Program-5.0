# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/EVA/session7/app
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/EVA/session7/app

# %%
# !pwd
# Out:
# /content/drive/My Drive/EVA/session7/app

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import torch
from torch.optim.lr_scheduler import StepLR
import torch.optim as optim
import torch.nn.functional as F

# %% [markdown]
# ## Import Dataset

# %%
from data_loader.CIFAR_data_pull import data_pull_CIFAR10

# %%
 trainloader,  testloader, classes =data_pull_CIFAR10()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True

# %%
classes
# Out:
# ('plane',
#  'car',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck')

# %% [markdown]
# ## Check Summary

# %%
from utils.summary import get_summary
from model import CIFAR
from model.CIFAR import CIFAR_Depthwise_Separable_Model

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model=CIFAR.CIFAR_Depthwise_Separable_Model().to(device)

# %%
get_summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          Dropout2d-4           [-1, 32, 32, 32]               0
#             Conv2d-5          [-1, 128, 32, 32]          36,864
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#               ReLU-7          [-1, 128, 32, 32]               0
#          Dropout2d-8          [-1, 128, 32, 32]               0
#          MaxPool2d-9          [-1, 128, 16, 16]               0
#            Conv2d-10           [-1, 32, 16, 16]           4,096
#            Conv2d-11           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-12           [-1, 64, 16, 16]             128
#              ReLU-13           [-1, 64, 16, 16]               0
# ...

# %% [markdown]
# ## Run The model

# %%
from trainer import train_test_fit

# %%
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.95)
# scheduler = StepLR(optimizer, step_size=9, gamma=0.1)
train_test_fit.fit(model, device, trainloader,testloader, 25)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.5560657978057861 Batch_id=390 Accuracy=40.71: 100%|██████████| 391/391 [00:20<00:00, 18.66it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 1.1589, Accuracy: 5733/10000 (57.33%)
#
# EPOCH: 1
# Loss=1.0467650890350342 Batch_id=390 Accuracy=58.33: 100%|██████████| 391/391 [00:20<00:00, 18.71it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.9057, Accuracy: 6808/10000 (68.08%)
#
# EPOCH: 2
# Loss=1.265596866607666 Batch_id=390 Accuracy=65.12: 100%|██████████| 391/391 [00:20<00:00, 19.22it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.7794, Accuracy: 7228/10000 (72.28%)
#
# EPOCH: 3
# Loss=0.8790737390518188 Batch_id=390 Accuracy=69.24: 100%|██████████| 391/391 [00:20<00:00, 19.00it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.7071, Accuracy: 7558/10000 (75.58%)
#
# EPOCH: 4
# ...

# %% [markdown]
# ## Class Labels Test Accuracy

# %%
train_test_fit.Class_Accuracy(device, model, testloader, classes)
# Out:
# Accuracy of plane : 89 %
# Accuracy of   car : 95 %
# Accuracy of  bird : 76 %
# Accuracy of   cat : 60 %
# Accuracy of  deer : 84 %
# Accuracy of   dog : 70 %
# Accuracy of  frog : 78 %
# Accuracy of horse : 94 %
# Accuracy of  ship : 95 %
# Accuracy of truck : 92 %
