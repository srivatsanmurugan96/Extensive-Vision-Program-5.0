# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 44.38 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
cd /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/
# Out:
# /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3

# %%
# !cp "/content/gdrive/My Drive/EVA/Session_13/Assignment_B/Assignement_B_new/yolov3-spp-ultralytics.pt" "/content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3-master/weights/"

# %%
ls
# Out:
#  annotation_tool/   output/        runs/           'ubdivisions=1'
#  cfg/               __pycache__/   test.py          utils/
#  data/              README.md      test_video.mp4   vim.exe.stackdump
#  detect.py          results.json   ting             weights/
#  models.py          results.png    train.py

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 70
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=70, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-27 07:28:06.937969: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2858 found, 131 missing, 38 empty, 0 duplicate, for 3027 images): 100% 3027/3027 [10:54<00:00,  4.63it/s]
# Caching images (1.7GB): 100% 3027/3027 [12:40<00:00,  3.98it/s]
# Reading image shapes: 100% 318/318 [01:16<00:00,  4.18it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/3585 data/customdata/images/01-prince-boots - Copy.jpg: 512x448 5 bootss, Done. (0.044s)
# image 2/3585 data/customdata/images/026f0ffddc.jpg: 384x512 1 masks, Done. (0.037s)
# image 3/3585 data/customdata/images/032620_LS_covid-masks_inline-680.jpg: 320x512 1 hardhats, 1 masks, Done. (0.033s)
# image 4/3585 data/customdata/images/046acbc8e1.jpg: 384x512 1 masks, Done. (0.037s)
# ...

# %%
cd /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/data/customdata/
# Out:
# /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/data/customdata

# %%
# !mkdir videos

# %%
# !cp "/content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/test_video.mp4" "/content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/data/customdata/videos"

# %%
cd /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/
# Out:
# /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3

# %%
# !python detect.py --source data/customdata/videos --conf-thres 0.1
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='data/customdata/videos', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# video 1/1 (1/820) data/customdata/videos/test_video.mp4: 320x512 12 hardhats, Done. (0.033s)
# video 1/1 (2/820) data/customdata/videos/test_video.mp4: 320x512 12 hardhats, Done. (0.033s)
# video 1/1 (3/820) data/customdata/videos/test_video.mp4: 320x512 12 hardhats, Done. (0.026s)
# video 1/1 (4/820) data/customdata/videos/test_video.mp4: 320x512 12 hardhats, Done. (0.024s)
# video 1/1 (5/820) data/customdata/videos/test_video.mp4: 320x512 12 hardhats, Done. (0.024s)
# ...

# %%
cd /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/output/
# Out:
# /content/gdrive/My Drive/EVA/Session_13/Assignment_B/YoloV3/output

# %%
from IPython.display import Image
Image('VIP_1.png', width=700)

# %%
from IPython.display import Image
Image('VIP_2.png', width=700)
